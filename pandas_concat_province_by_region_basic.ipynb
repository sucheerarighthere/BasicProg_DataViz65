# %% [markdown]
# <a href="https://colab.research.google.com/github/sucheerarighthere/BasicProg_DataViz65/blob/main/pandas_concat_province_by_region_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # การใช้ pandas.concat ในการรวม DataFrame
# https://th.wikipedia.org/wiki/จังหวัดของประเทศไทย

# %%
import pandas as pd
print(f'pandas version: {pd.__version__}')
# Out:
# pandas version: 0.23.0

# %%
west=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/province_in_region/W.csv')
west
# Out:
#   ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0            กาญจนบุรี           Kanchanaburi             839776
# 1                  ตาก                    Tak             525684
# 2      ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
# 3             เพชรบุรี            Phetchaburi             464033
# 4              ราชบุรี             Ratchaburi             839075
#
#    พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2] ตัวย่อ อักษรไทย  \
# 0           19483.2                             43.1    0.733              กจ
# 1           16406.6                             32.0    0.735              ตก
# 2            6367.6                             80.0    0.868              ปข
# 3            6225.1                             74.5    0.798              พบ
# 4            5196.5                            161.5    0.726              รบ
#
#   ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0               KRI        TH-71      TH50
# 1               TAK        TH-63      TH08
# 2               PKN        TH-77      TH57
# 3               PBI        TH-76      TH56
# 4               RBR        TH-70      TH52

# %%
east=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/province_in_region/E.csv')
east
# Out:
#   ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0             จันทบุรี            Chanthaburi             514616
# 1           ฉะเชิงเทรา           Chachoengsao             673933
# 2               ชลบุรี              Chon Buri            1509125
# 3                 ตราด                   Trat             220921
# 4           ปราจีนบุรี           Prachin Buri             466572
# 5                ระยอง                 Rayong             626402
# 6              สระแก้ว                Sa Kaeo             485632
#
#    พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2] ตัวย่อ อักษรไทย  \
# 0            6338.0                             81.2    0.754              จบ
# 1            5351.0                            125.9    0.708              ฉช
# 2            4363.0                            345.9    0.889              ชบ
# 3            2819.0                             78.4    0.675              ตร
# 4            4762.4                             98.0    0.755              ปจ
# 5            3552.0                            176.4    0.802              รย
# 6            7195.1                             75.6    0.688              สก
#
#   ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0               CTI        TH-22      TH48
# 1               CCO        TH-24      TH44
# 2               CBI        TH-20      TH46
# 3               TRT        TH-23      TH49
# 4               PRI        TH-25      TH74
# 5               RYG        TH-21      TH47
# 6               SKW        TH-27      TH80

# %%
df=pd.concat([west, east])
df
# Out:
#   ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0            กาญจนบุรี           Kanchanaburi             839776
# 1                  ตาก                    Tak             525684
# 2      ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
# 3             เพชรบุรี            Phetchaburi             464033
# 4              ราชบุรี             Ratchaburi             839075
# 0             จันทบุรี            Chanthaburi             514616
# 1           ฉะเชิงเทรา           Chachoengsao             673933
# 2               ชลบุรี              Chon Buri            1509125
# 3                 ตราด                   Trat             220921
# 4           ปราจีนบุรี           Prachin Buri             466572
# 5                ระยอง                 Rayong             626402
# 6              สระแก้ว                Sa Kaeo             485632
#
#    พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2] ตัวย่อ อักษรไทย  \
# 0           19483.2                             43.1    0.733              กจ
# 1           16406.6                             32.0    0.735              ตก
# 2            6367.6                             80.0    0.868              ปข
# 3            6225.1                             74.5    0.798              พบ
# 4            5196.5                            161.5    0.726              รบ
# 0            6338.0                             81.2    0.754              จบ
# 1            5351.0                            125.9    0.708              ฉช
# 2            4363.0                            345.9    0.889              ชบ
# 3            2819.0                             78.4    0.675              ตร
# 4            4762.4                             98.0    0.755              ปจ
# 5            3552.0                            176.4    0.802              รย
# 6            7195.1                             75.6    0.688              สก
#
#   ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0               KRI        TH-71      TH50
# 1               TAK        TH-63      TH08
# 2               PKN        TH-77      TH57
# 3               PBI        TH-76      TH56
# 4               RBR        TH-70      TH52
# 0               CTI        TH-22      TH48
# 1               CCO        TH-24      TH44
# 2               CBI        TH-20      TH46
# 3               TRT        TH-23      TH49
# 4               PRI        TH-25      TH74
# 5               RYG        TH-21      TH47
# 6               SKW        TH-27      TH80

# %%
df=pd.concat([west, east], ignore_index=True)
df
# Out:
#    ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0             กาญจนบุรี           Kanchanaburi             839776
# 1                   ตาก                    Tak             525684
# 2       ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
# 3              เพชรบุรี            Phetchaburi             464033
# 4               ราชบุรี             Ratchaburi             839075
# 5              จันทบุรี            Chanthaburi             514616
# 6            ฉะเชิงเทรา           Chachoengsao             673933
# 7                ชลบุรี              Chon Buri            1509125
# 8                  ตราด                   Trat             220921
# 9            ปราจีนบุรี           Prachin Buri             466572
# 10                ระยอง                 Rayong             626402
# 11              สระแก้ว                Sa Kaeo             485632
#
#     พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2]  \
# 0            19483.2                             43.1    0.733
# 1            16406.6                             32.0    0.735
# 2             6367.6                             80.0    0.868
# 3             6225.1                             74.5    0.798
# 4             5196.5                            161.5    0.726
# 5             6338.0                             81.2    0.754
# 6             5351.0                            125.9    0.708
# 7             4363.0                            345.9    0.889
# 8             2819.0                             78.4    0.675
# 9             4762.4                             98.0    0.755
# 10            3552.0                            176.4    0.802
# 11            7195.1                             75.6    0.688
#
#    ตัวย่อ อักษรไทย ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0               กจ               KRI        TH-71      TH50
# 1               ตก               TAK        TH-63      TH08
# 2               ปข               PKN        TH-77      TH57
# 3               พบ               PBI        TH-76      TH56
# 4               รบ               RBR        TH-70      TH52
# 5               จบ               CTI        TH-22      TH48
# 6               ฉช               CCO        TH-24      TH44
# 7               ชบ               CBI        TH-20      TH46
# 8               ตร               TRT        TH-23      TH49
# 9               ปจ               PRI        TH-25      TH74
# 10              รย               RYG        TH-21      TH47
# 11              สก               SKW        TH-27      TH80

# %%
df=pd.concat([west, east], keys=['ตะวันตก', 'ตะวันออก'])
df
# Out:
#            ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# ตะวันตก  0            กาญจนบุรี           Kanchanaburi             839776
#          1                  ตาก                    Tak             525684
#          2      ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
#          3             เพชรบุรี            Phetchaburi             464033
#          4              ราชบุรี             Ratchaburi             839075
# ตะวันออก 0             จันทบุรี            Chanthaburi             514616
#          1           ฉะเชิงเทรา           Chachoengsao             673933
#          2               ชลบุรี              Chon Buri            1509125
#          3                 ตราด                   Trat             220921
#          4           ปราจีนบุรี           Prachin Buri             466572
#          5                ระยอง                 Rayong             626402
#          6              สระแก้ว                Sa Kaeo             485632
#
#             พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2]  \
# ตะวันตก  0           19483.2                             43.1    0.733
#          1           16406.6                             32.0    0.735
#          2            6367.6                             80.0    0.868
#          3            6225.1                             74.5    0.798
#          4            5196.5                            161.5    0.726
# ตะวันออก 0            6338.0                             81.2    0.754
#          1            5351.0                            125.9    0.708
#          2            4363.0                            345.9    0.889
#          3            2819.0                             78.4    0.675
#          4            4762.4                             98.0    0.755
#          5            3552.0                            176.4    0.802
#          6            7195.1                             75.6    0.688
#
#            ตัวย่อ อักษรไทย ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# ตะวันตก  0              กจ               KRI        TH-71      TH50
#          1              ตก               TAK        TH-63      TH08
#          2              ปข               PKN        TH-77      TH57
#          3              พบ               PBI        TH-76      TH56
#          4              รบ               RBR        TH-70      TH52
# ตะวันออก 0              จบ               CTI        TH-22      TH48
#          1              ฉช               CCO        TH-24      TH44
#          2              ชบ               CBI        TH-20      TH46
#          3              ตร               TRT        TH-23      TH49
#          4              ปจ               PRI        TH-25      TH74
#          5              รย               RYG        TH-21      TH47
#          6              สก               SKW        TH-27      TH80

# %%
df.to_csv('data/p1.csv')

# %%
south=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/province_in_region/S.csv')
south
# Out:
#    ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0                กระบี่                  Krabi             432704
# 1                 ชุมพร               Chumphon             489964
# 2                  ตรัง                  Trang             622659
# 3         นครศรีธรรมราช    Nakhon Si Thammarat            1522561
# 4              นราธิวาส             Narathiwat             737162
# 5               ปัตตานี                Pattani             655259
# 6                 พังงา               Phangnga             253112
# 7                พัทลุง            Phatthalung             509534
# 8                ภูเก็ต                 Phuket             345067
# 9                  ยะลา                   Yala             500814
# 10                ระนอง                 Ranong             183079
# 11                สงขลา               Songkhla            1357023
# 12                 สตูล                  Satun             297163
# 13         สุราษฎร์ธานี            Surat Thani            1046772
#
#     พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2]  \
# 0            4708.50                            91.90    0.805
# 1            6009.00                            81.50    0.710
# 2            4917.50                           126.60    0.692
# 3            9942.50                           153.10    0.769
# 4            4475.40                           164.70    0.636
# 5            1940.40                           337.70    0.698
# 6            4170.00                            60.70    0.758
# 7            3424.50                           148.80    0.713
# 8             543.00                           635.50    0.921
# 9            4521.08                           110.77    0.687
# 10           3298.00                            55.50    0.678
# 11           7393.90                           183.50    0.681
# 12           2479.00                           119.90    0.655
# 13          12891.50                            81.20    0.849
#
#    ตัวย่อ อักษรไทย ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0               กบ               KBI        TH-81      TH63
# 1               ชพ               CPN        TH-86      TH58
# 2               ตง               TRG        TH-92      TH65
# 3               นศ               NRT        TH-80      TH64
# 4               นธ               NWT        TH-96      TH31
# 5               ปน               PTN        TH-94      TH69
# 6               พง               PNA        TH-82      TH61
# 7               พท               PLG        TH-93      TH66
# 8               ภก               PKT        TH-83      TH62
# 9               ยล               YLA        TH-95      TH70
# 10              รน               RNG        TH-85      TH59
# 11              สข               SKA        TH-90      TH68
# 12              สต               STN        TH-91      TH67
# 13              สฎ               SNI        TH-84      TH60

# %%
df=pd.concat([west, east, south], keys=['ตะวันตก', 'ตะวันออก', 'ใต้'])
df
# Out:
#             ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# ตะวันตก  0             กาญจนบุรี           Kanchanaburi             839776
#          1                   ตาก                    Tak             525684
#          2       ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
#          3              เพชรบุรี            Phetchaburi             464033
#          4               ราชบุรี             Ratchaburi             839075
# ตะวันออก 0              จันทบุรี            Chanthaburi             514616
#          1            ฉะเชิงเทรา           Chachoengsao             673933
#          2                ชลบุรี              Chon Buri            1509125
#          3                  ตราด                   Trat             220921
#          4            ปราจีนบุรี           Prachin Buri             466572
#          5                 ระยอง                 Rayong             626402
#          6               สระแก้ว                Sa Kaeo             485632
# ใต้      0                กระบี่                  Krabi             432704
#          1                 ชุมพร               Chumphon             489964
#          2                  ตรัง                  Trang             622659
#          3         นครศรีธรรมราช    Nakhon Si Thammarat            1522561
#          4              นราธิวาส             Narathiwat             737162
#          5               ปัตตานี                Pattani             655259
#          6                 พังงา               Phangnga             253112
#          7                พัทลุง            Phatthalung             509534
#          8                ภูเก็ต                 Phuket             345067
#          9                  ยะลา                   Yala             500814
#          10                ระนอง                 Ranong             183079
#          11                สงขลา               Songkhla            1357023
#          12                 สตูล                  Satun             297163
#          13         สุราษฎร์ธานี            Surat Thani            1046772
#
#              พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2]  \
# ตะวันตก  0           19483.20                            43.10    0.733
#          1           16406.60                            32.00    0.735
#          2            6367.60                            80.00    0.868
#          3            6225.10                            74.50    0.798
#          4            5196.50                           161.50    0.726
# ตะวันออก 0            6338.00                            81.20    0.754
#          1            5351.00                           125.90    0.708
#          2            4363.00                           345.90    0.889
#          3            2819.00                            78.40    0.675
#          4            4762.40                            98.00    0.755
#          5            3552.00                           176.40    0.802
#          6            7195.10                            75.60    0.688
# ใต้      0            4708.50                            91.90    0.805
#          1            6009.00                            81.50    0.710
#          2            4917.50                           126.60    0.692
#          3            9942.50                           153.10    0.769
#          4            4475.40                           164.70    0.636
#          5            1940.40                           337.70    0.698
#          6            4170.00                            60.70    0.758
#          7            3424.50                           148.80    0.713
#          8             543.00                           635.50    0.921
#          9            4521.08                           110.77    0.687
#          10           3298.00                            55.50    0.678
#          11           7393.90                           183.50    0.681
#          12           2479.00                           119.90    0.655
#          13          12891.50                            81.20    0.849
#
#             ตัวย่อ อักษรไทย ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# ตะวันตก  0               กจ               KRI        TH-71      TH50
#          1               ตก               TAK        TH-63      TH08
#          2               ปข               PKN        TH-77      TH57
#          3               พบ               PBI        TH-76      TH56
#          4               รบ               RBR        TH-70      TH52
# ตะวันออก 0               จบ               CTI        TH-22      TH48
#          1               ฉช               CCO        TH-24      TH44
#          2               ชบ               CBI        TH-20      TH46
#          3               ตร               TRT        TH-23      TH49
#          4               ปจ               PRI        TH-25      TH74
#          5               รย               RYG        TH-21      TH47
#          6               สก               SKW        TH-27      TH80
# ใต้      0               กบ               KBI        TH-81      TH63
#          1               ชพ               CPN        TH-86      TH58
#          2               ตง               TRG        TH-92      TH65
#          3               นศ               NRT        TH-80      TH64
#          4               นธ               NWT        TH-96      TH31
#          5               ปน               PTN        TH-94      TH69
#          6               พง               PNA        TH-82      TH61
#          7               พท               PLG        TH-93      TH66
#          8               ภก               PKT        TH-83      TH62
#          9               ยล               YLA        TH-95      TH70
#          10              รน               RNG        TH-85      TH59
#          11              สข               SKA        TH-90      TH68
#          12              สต               STN        TH-91      TH67
#          13              สฎ               SNI        TH-84      TH60

# %%
df.to_csv('data/p.csv')

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      level_0  level_1 ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  \
# 0    ตะวันตก        0            กาญจนบุรี           Kanchanaburi
# 1    ตะวันตก        1                  ตาก                    Tak
# 2    ตะวันตก        2      ประจวบคีรีขันธ์    Prachuap Khiri Khan
# 3    ตะวันตก        3             เพชรบุรี            Phetchaburi
# 4    ตะวันตก        4              ราชบุรี             Ratchaburi
# 5   ตะวันออก        0             จันทบุรี            Chanthaburi
# 6   ตะวันออก        1           ฉะเชิงเทรา           Chachoengsao
# 7   ตะวันออก        2               ชลบุรี              Chon Buri
# 8   ตะวันออก        3                 ตราด                   Trat
# 9   ตะวันออก        4           ปราจีนบุรี           Prachin Buri
# 10  ตะวันออก        5                ระยอง                 Rayong
# 11  ตะวันออก        6              สระแก้ว                Sa Kaeo
# 12       ใต้        0               กระบี่                  Krabi
# 13       ใต้        1                ชุมพร               Chumphon
# 14       ใต้        2                 ตรัง                  Trang
# 15       ใต้        3        นครศรีธรรมราช    Nakhon Si Thammarat
# 16       ใต้        4             นราธิวาส             Narathiwat
# 17       ใต้        5              ปัตตานี                Pattani
# 18       ใต้        6                พังงา               Phangnga
# 19       ใต้        7               พัทลุง            Phatthalung
# 20       ใต้        8               ภูเก็ต                 Phuket
# 21       ใต้        9                 ยะลา                   Yala
# 22       ใต้       10                ระนอง                 Ranong
# 23       ใต้       11                สงขลา               Songkhla
# 24       ใต้       12                 สตูล                  Satun
# 25       ใต้       13         สุราษฎร์ธานี            Surat Thani
#
#     จำนวนประชากร (คน)  พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  \
# 0              839776          19483.20                            43.10
# 1              525684          16406.60                            32.00
# 2              509134           6367.60                            80.00
# 3              464033           6225.10                            74.50
# 4              839075           5196.50                           161.50
# 5              514616           6338.00                            81.20
# 6              673933           5351.00                           125.90
# 7             1509125           4363.00                           345.90
# 8              220921           2819.00                            78.40
# 9              466572           4762.40                            98.00
# 10             626402           3552.00                           176.40
# 11             485632           7195.10                            75.60
# 12             432704           4708.50                            91.90
# 13             489964           6009.00                            81.50
# 14             622659           4917.50                           126.60
# 15            1522561           9942.50                           153.10
# 16             737162           4475.40                           164.70
# 17             655259           1940.40                           337.70
# 18             253112           4170.00                            60.70
# 19             509534           3424.50                           148.80
# 20             345067            543.00                           635.50
# 21             500814           4521.08                           110.77
# 22             183079           3298.00                            55.50
# 23            1357023           7393.90                           183.50
# 24             297163           2479.00                           119.90
# 25            1046772          12891.50                            81.20
#
#     ดพม.[2] ตัวย่อ อักษรไทย ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0     0.733              กจ               KRI        TH-71      TH50
# 1     0.735              ตก               TAK        TH-63      TH08
# 2     0.868              ปข               PKN        TH-77      TH57
# 3     0.798              พบ               PBI        TH-76      TH56
# 4     0.726              รบ               RBR        TH-70      TH52
# 5     0.754              จบ               CTI        TH-22      TH48
# 6     0.708              ฉช               CCO        TH-24      TH44
# 7     0.889              ชบ               CBI        TH-20      TH46
# 8     0.675              ตร               TRT        TH-23      TH49
# 9     0.755              ปจ               PRI        TH-25      TH74
# 10    0.802              รย               RYG        TH-21      TH47
# 11    0.688              สก               SKW        TH-27      TH80
# 12    0.805              กบ               KBI        TH-81      TH63
# 13    0.710              ชพ               CPN        TH-86      TH58
# 14    0.692              ตง               TRG        TH-92      TH65
# 15    0.769              นศ               NRT        TH-80      TH64
# 16    0.636              นธ               NWT        TH-96      TH31
# 17    0.698              ปน               PTN        TH-94      TH69
# 18    0.758              พง               PNA        TH-82      TH61
# 19    0.713              พท               PLG        TH-93      TH66
# 20    0.921              ภก               PKT        TH-83      TH62
# 21    0.687              ยล               YLA        TH-95      TH70
# 22    0.678              รน               RNG        TH-85      TH59
# 23    0.681              สข               SKA        TH-90      TH68
# 24    0.655              สต               STN        TH-91      TH67
# 25    0.849              สฎ               SNI        TH-84      TH60

# %%
df.rename(index=str, columns={"level_0": "region"}, inplace=True)
df
# Out:
#       region  level_1 ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  \
# 0    ตะวันตก        0            กาญจนบุรี           Kanchanaburi
# 1    ตะวันตก        1                  ตาก                    Tak
# 2    ตะวันตก        2      ประจวบคีรีขันธ์    Prachuap Khiri Khan
# 3    ตะวันตก        3             เพชรบุรี            Phetchaburi
# 4    ตะวันตก        4              ราชบุรี             Ratchaburi
# 5   ตะวันออก        0             จันทบุรี            Chanthaburi
# 6   ตะวันออก        1           ฉะเชิงเทรา           Chachoengsao
# 7   ตะวันออก        2               ชลบุรี              Chon Buri
# 8   ตะวันออก        3                 ตราด                   Trat
# 9   ตะวันออก        4           ปราจีนบุรี           Prachin Buri
# 10  ตะวันออก        5                ระยอง                 Rayong
# 11  ตะวันออก        6              สระแก้ว                Sa Kaeo
# 12       ใต้        0               กระบี่                  Krabi
# 13       ใต้        1                ชุมพร               Chumphon
# 14       ใต้        2                 ตรัง                  Trang
# 15       ใต้        3        นครศรีธรรมราช    Nakhon Si Thammarat
# 16       ใต้        4             นราธิวาส             Narathiwat
# 17       ใต้        5              ปัตตานี                Pattani
# 18       ใต้        6                พังงา               Phangnga
# 19       ใต้        7               พัทลุง            Phatthalung
# 20       ใต้        8               ภูเก็ต                 Phuket
# 21       ใต้        9                 ยะลา                   Yala
# 22       ใต้       10                ระนอง                 Ranong
# 23       ใต้       11                สงขลา               Songkhla
# 24       ใต้       12                 สตูล                  Satun
# 25       ใต้       13         สุราษฎร์ธานี            Surat Thani
#
#     จำนวนประชากร (คน)  พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  \
# 0              839776          19483.20                            43.10
# 1              525684          16406.60                            32.00
# 2              509134           6367.60                            80.00
# 3              464033           6225.10                            74.50
# 4              839075           5196.50                           161.50
# 5              514616           6338.00                            81.20
# 6              673933           5351.00                           125.90
# 7             1509125           4363.00                           345.90
# 8              220921           2819.00                            78.40
# 9              466572           4762.40                            98.00
# 10             626402           3552.00                           176.40
# 11             485632           7195.10                            75.60
# 12             432704           4708.50                            91.90
# 13             489964           6009.00                            81.50
# 14             622659           4917.50                           126.60
# 15            1522561           9942.50                           153.10
# 16             737162           4475.40                           164.70
# 17             655259           1940.40                           337.70
# 18             253112           4170.00                            60.70
# 19             509534           3424.50                           148.80
# 20             345067            543.00                           635.50
# 21             500814           4521.08                           110.77
# 22             183079           3298.00                            55.50
# 23            1357023           7393.90                           183.50
# 24             297163           2479.00                           119.90
# 25            1046772          12891.50                            81.20
#
#     ดพม.[2] ตัวย่อ อักษรไทย ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0     0.733              กจ               KRI        TH-71      TH50
# 1     0.735              ตก               TAK        TH-63      TH08
# 2     0.868              ปข               PKN        TH-77      TH57
# 3     0.798              พบ               PBI        TH-76      TH56
# 4     0.726              รบ               RBR        TH-70      TH52
# 5     0.754              จบ               CTI        TH-22      TH48
# 6     0.708              ฉช               CCO        TH-24      TH44
# 7     0.889              ชบ               CBI        TH-20      TH46
# 8     0.675              ตร               TRT        TH-23      TH49
# 9     0.755              ปจ               PRI        TH-25      TH74
# 10    0.802              รย               RYG        TH-21      TH47
# 11    0.688              สก               SKW        TH-27      TH80
# 12    0.805              กบ               KBI        TH-81      TH63
# 13    0.710              ชพ               CPN        TH-86      TH58
# 14    0.692              ตง               TRG        TH-92      TH65
# 15    0.769              นศ               NRT        TH-80      TH64
# 16    0.636              นธ               NWT        TH-96      TH31
# 17    0.698              ปน               PTN        TH-94      TH69
# 18    0.758              พง               PNA        TH-82      TH61
# 19    0.713              พท               PLG        TH-93      TH66
# 20    0.921              ภก               PKT        TH-83      TH62
# 21    0.687              ยล               YLA        TH-95      TH70
# 22    0.678              รน               RNG        TH-85      TH59
# 23    0.681              สข               SKA        TH-90      TH68
# 24    0.655              สต               STN        TH-91      TH67
# 25    0.849              สฎ               SNI        TH-84      TH60

# %%
df.drop(['level_1'], axis=1, inplace=True)
df
# Out:
#       region ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0    ตะวันตก            กาญจนบุรี           Kanchanaburi             839776
# 1    ตะวันตก                  ตาก                    Tak             525684
# 2    ตะวันตก      ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
# 3    ตะวันตก             เพชรบุรี            Phetchaburi             464033
# 4    ตะวันตก              ราชบุรี             Ratchaburi             839075
# 5   ตะวันออก             จันทบุรี            Chanthaburi             514616
# 6   ตะวันออก           ฉะเชิงเทรา           Chachoengsao             673933
# 7   ตะวันออก               ชลบุรี              Chon Buri            1509125
# 8   ตะวันออก                 ตราด                   Trat             220921
# 9   ตะวันออก           ปราจีนบุรี           Prachin Buri             466572
# 10  ตะวันออก                ระยอง                 Rayong             626402
# 11  ตะวันออก              สระแก้ว                Sa Kaeo             485632
# 12       ใต้               กระบี่                  Krabi             432704
# 13       ใต้                ชุมพร               Chumphon             489964
# 14       ใต้                 ตรัง                  Trang             622659
# 15       ใต้        นครศรีธรรมราช    Nakhon Si Thammarat            1522561
# 16       ใต้             นราธิวาส             Narathiwat             737162
# 17       ใต้              ปัตตานี                Pattani             655259
# 18       ใต้                พังงา               Phangnga             253112
# 19       ใต้               พัทลุง            Phatthalung             509534
# 20       ใต้               ภูเก็ต                 Phuket             345067
# 21       ใต้                 ยะลา                   Yala             500814
# 22       ใต้                ระนอง                 Ranong             183079
# 23       ใต้                สงขลา               Songkhla            1357023
# 24       ใต้                 สตูล                  Satun             297163
# 25       ใต้         สุราษฎร์ธานี            Surat Thani            1046772
#
#     พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2]  \
# 0           19483.20                            43.10    0.733
# 1           16406.60                            32.00    0.735
# 2            6367.60                            80.00    0.868
# 3            6225.10                            74.50    0.798
# 4            5196.50                           161.50    0.726
# 5            6338.00                            81.20    0.754
# 6            5351.00                           125.90    0.708
# 7            4363.00                           345.90    0.889
# 8            2819.00                            78.40    0.675
# 9            4762.40                            98.00    0.755
# 10           3552.00                           176.40    0.802
# 11           7195.10                            75.60    0.688
# 12           4708.50                            91.90    0.805
# 13           6009.00                            81.50    0.710
# 14           4917.50                           126.60    0.692
# 15           9942.50                           153.10    0.769
# 16           4475.40                           164.70    0.636
# 17           1940.40                           337.70    0.698
# 18           4170.00                            60.70    0.758
# 19           3424.50                           148.80    0.713
# 20            543.00                           635.50    0.921
# 21           4521.08                           110.77    0.687
# 22           3298.00                            55.50    0.678
# 23           7393.90                           183.50    0.681
# 24           2479.00                           119.90    0.655
# 25          12891.50                            81.20    0.849
#
#    ตัวย่อ อักษรไทย ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0               กจ               KRI        TH-71      TH50
# 1               ตก               TAK        TH-63      TH08
# 2               ปข               PKN        TH-77      TH57
# 3               พบ               PBI        TH-76      TH56
# 4               รบ               RBR        TH-70      TH52
# 5               จบ               CTI        TH-22      TH48
# 6               ฉช               CCO        TH-24      TH44
# 7               ชบ               CBI        TH-20      TH46
# 8               ตร               TRT        TH-23      TH49
# 9               ปจ               PRI        TH-25      TH74
# 10              รย               RYG        TH-21      TH47
# 11              สก               SKW        TH-27      TH80
# 12              กบ               KBI        TH-81      TH63
# 13              ชพ               CPN        TH-86      TH58
# 14              ตง               TRG        TH-92      TH65
# 15              นศ               NRT        TH-80      TH64
# 16              นธ               NWT        TH-96      TH31
# 17              ปน               PTN        TH-94      TH69
# 18              พง               PNA        TH-82      TH61
# 19              พท               PLG        TH-93      TH66
# 20              ภก               PKT        TH-83      TH62
# 21              ยล               YLA        TH-95      TH70
# 22              รน               RNG        TH-85      TH59
# 23              สข               SKA        TH-90      TH68
# 24              สต               STN        TH-91      TH67
# 25              สฎ               SNI        TH-84      TH60

# %%
df.to_csv('data/p3.csv', index=False)
