# %% [markdown]
# <a href="https://colab.research.google.com/github/sucheerarighthere/BasicProg_DataViz65/blob/main/DataViz01_Table_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv') #พันธุ์ดอกไม้
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
set(df['Name']) #ดูชื่อดอกไม้
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df['Name'].unique() #เอาค่าที่ไม่ซ้ำแต่ถ้าซ้ำก็เลือกมาแค่ค่าเดียว unique
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# Petal กลีบดอก / Sepal กลีบเลี้ยง

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %% [markdown]
# ### Parallel Coordinates

# %%
pd.plotting.parallel_coordinates(df, 'Name') # =ชื่อเหมือนกันสีเดียวกัน

# %% [markdown]
# setosa     กลีบเลี้ยงไม่ยาวไม่กว้าง กลีบดอกจะยาวและกว้าง
#
#
# versicolor กลีบเลี้ยงกลีบดอกดอกยาวใกล้ๆกัน
#
# virginica  กลีบเลี้ยงกลีบดอกดอกยาวใกล้ๆกัน

# %% [markdown]
# ## select column to shows

# %%
pd.plotting.parallel_coordinates(df, 'Name',cols = ['SepalLength','PetalLength','SepalLength','PetalLength'])

# %%
pd.plotting.parallel_coordinates(df, 'Name',cols = ['SepalLength','PetalLength'])

# %%
pd.plotting.parallel_coordinates(df, 'Name',cols = ['SepalLength','PetalLength']);

# %% [markdown]
# change color
# [ข้อความลิงก์](https://matplotlib.org/stable/tutorials/colors/colors.html)

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=['r','y','k'])

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5],[0,0,0.8],[0.2,0.4,0.7]])

# %% [markdown]
# ## Quiz5

# %%
pd.plotting.parallel_coordinates(df,'Name',color = ['#A73B24','#633974','#88B46C'])
